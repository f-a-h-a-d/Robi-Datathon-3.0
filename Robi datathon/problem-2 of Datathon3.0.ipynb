# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Import the data
purchase_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/purchase.csv")
boxes_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/boxes.csv")
problem_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/problem 2.csv")

problem_df



#len(pd.unique(purchase_df['BOX_COUNT']))
#len(pd.unique(boxes_df['BOX_ID']))
# Out:
#          MAGIC_KEY
# 0      2C0B5F97180
# 1      2C2F659EF00
# 2      29D629EDF20
# 3      2A7073E2FF0
# 4      2A9B9BE1210
# ...            ...
# 43513  2C49A3D7EAD
# 43514  2C49C75F0D8
# 43515  2C49CA2A632
# 43516  2C49D52753F
# 43517  2C49DF0ADB4
#
# [43518 rows x 1 columns]

# %%
max_box_id = boxes_df['BOX_ID'].max()

min_box_id = boxes_df['BOX_ID'].min()

print(max_box_id)
print(min_box_id)
# Out:
# 290
# 1

# %%
#Removing all the nan and zero BOX COUNT Values

#Remove for -1 values
purchase_df = purchase_df[purchase_df['BOX_COUNT'] >= 0]

#Remove for nan values
purchase_df = purchase_df.dropna(subset=['BOX_COUNT'])



#Drop Box id which is not present in boxes
indexAge = purchase_df[ (purchase_df['BOX_ID'] < min_box_id) | (purchase_df['BOX_ID'] > max_box_id) ].index
purchase_df.drop(indexAge , inplace=True)

#Drop Date which Not needed
# indexAge = purchase_df[ (purchase_df['PURCHASE_DATE'] <"2019-03-01") | (purchase_df['PURCHASE_DATE'] >"2019-03-15") ].index
# purchase_df.drop(indexAge , inplace=True)



#Changing the type of the columns
purchase_df['PURCHASE_DATE'] = pd.to_datetime(purchase_df['PURCHASE_DATE'], dayfirst = True)
purchase_df['MAGIC_KEY'] = purchase_df['MAGIC_KEY'].astype('string')
purchase_df['BOX_ID'] = purchase_df['BOX_ID'].astype('int')
purchase_df['BOX_COUNT'] = purchase_df['BOX_COUNT'].astype('int')



purchase_df.dtypes
# Out:
# PURCHASE_DATE    datetime64[ns]
# MAGIC_KEY        string[python]
# BOX_ID                    int64
# BOX_COUNT                 int64
# dtype: object

# %%
#Merging both the datasets
df_master = purchase_df.merge(boxes_df)

# %%
df_master = df_master.assign(TOTAL_PRICE = lambda x: (x['BOX_COUNT'] * x['UNIT_PRICE']))
df_master['PURCHASE_DATE'] = pd.to_datetime(df_master['PURCHASE_DATE'])

df_master
# Out:
#         PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT   QUALITY  \
# 0          2019-02-01  2CED678A247      12          1   Premium
# 1          2019-02-01  2BF58D91BA1      12          1   Premium
# 2          2019-02-01  2C3A3F7DB65      12          1   Premium
# 3          2019-02-01  2BD2641961A      12          1   Premium
# 4          2019-02-01  2BD2EAA1C90      12          1   Premium
# ...               ...          ...     ...        ...       ...
# 2455795    2018-10-14  2BE6A6A7E6C     169          1   Premium
# 2455796    2018-10-14  2C774DAC048     169          1   Premium
# 2455797    2018-10-14  2BD1A4A1DC5     169          1   Premium
# 2455798    2018-10-13  28D8EFAE836     264          2  Standard
# 2455799    2018-10-31  2C7754E946E     109          2   Premium
#
#                         DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  TOTAL_PRICE
# 0                   Home Delivery - CoD   8.0   1.5       12.98        12.98
# 1                   Home Delivery - CoD   8.0   1.5       12.98        12.98
# 2                   Home Delivery - CoD   8.0   1.5       12.98        12.98
# 3                   Home Delivery - CoD   8.0   1.5       12.98        12.98
# 4                   Home Delivery - CoD   8.0   1.5       12.98        12.98
# ...                                 ...   ...   ...         ...          ...
# 2455795  Delivery from Collection Point  14.0   2.9       23.98        23.98
# 2455796  Delivery from Collection Point  14.0   2.9       23.98        23.98
# 2455797  Delivery from Collection Point  14.0   2.9       23.98        23.98
# 2455798  Delivery from Collection Point  13.0   2.2       17.98        35.96
# 2455799  Delivery from Collection Point   0.0   4.2       15.96        31.92
#
# [2455800 rows x 10 columns]

# %%
#Drop Magic Key which is not in the problem

indexAge = df_master[ ((df_master['PURCHASE_DATE'] <"2019-03-01") | (df_master['PURCHASE_DATE'] >"2019-03-15")) & df_master['BOX_COUNT'] !=1 ].index
df_master.drop(indexAge , inplace=True)


df_master
# Out:
#         PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT  QUALITY  \
# 0          2019-02-01  2CED678A247      12          1  Premium
# 1          2019-02-01  2BF58D91BA1      12          1  Premium
# 2          2019-02-01  2C3A3F7DB65      12          1  Premium
# 3          2019-02-01  2BD2641961A      12          1  Premium
# 4          2019-02-01  2BD2EAA1C90      12          1  Premium
# ...               ...          ...     ...        ...      ...
# 2455793    2018-10-14  2C3A09E8FF2     169          1  Premium
# 2455794    2018-10-14  2CEEA608945     169          1  Premium
# 2455795    2018-10-14  2BE6A6A7E6C     169          1  Premium
# 2455796    2018-10-14  2C774DAC048     169          1  Premium
# 2455797    2018-10-14  2BD1A4A1DC5     169          1  Premium
#
#                         DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  TOTAL_PRICE
# 0                   Home Delivery - CoD   8.0   1.5       12.98        12.98
# 1                   Home Delivery - CoD   8.0   1.5       12.98        12.98
# 2                   Home Delivery - CoD   8.0   1.5       12.98        12.98
# 3                   Home Delivery - CoD   8.0   1.5       12.98        12.98
# 4                   Home Delivery - CoD   8.0   1.5       12.98        12.98
# ...                                 ...   ...   ...         ...          ...
# 2455793  Delivery from Collection Point  14.0   2.9       23.98        23.98
# 2455794  Delivery from Collection Point  14.0   2.9       23.98        23.98
# 2455795  Delivery from Collection Point  14.0   2.9       23.98        23.98
# 2455796  Delivery from Collection Point  14.0   2.9       23.98        23.98
# 2455797  Delivery from Collection Point  14.0   2.9       23.98        23.98
#
# [2453468 rows x 10 columns]

# %%
df_final = df_master.merge(problem_df)

df_final
# Out:
#        PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT  QUALITY  \
# 0         2019-02-02  2BF5D32A835      12          1  Premium
# 1         2018-11-24  2BF5D32A835      13          1  Premium
# 2         2019-01-02  2BF5D32A835      65          1  Premium
# 3         2019-02-03  2BFC2F3346E      12          1  Premium
# 4         2018-12-13  2BFC2F3346E       4          1  Premium
# ...              ...          ...     ...        ...      ...
# 168432    2018-11-15  2BD1F5B699C      41          1  Premium
# 168433    2018-12-09  2BCE8DEA05C      41          1  Premium
# 168434    2019-01-07  2BCE8DEA05C      10          1  Premium
# 168435    2019-01-05  2BE36918AD9      10          1  Premium
# 168436    2018-12-01  2BE36918AD9      14          1  Premium
#
#                        DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  TOTAL_PRICE
# 0                  Home Delivery - CoD   8.0   1.5       12.98        12.98
# 1                  Home Delivery - CoD   8.0   1.6       12.98        12.98
# 2       Delivery from Collection Point   8.0   1.1        9.98         9.98
# 3                  Home Delivery - CoD   8.0   1.5       12.98        12.98
# 4                  Home Delivery - CoD   0.0   2.5       11.96        11.96
# ...                                ...   ...   ...         ...          ...
# 168432             Home Delivery - CoD  12.0   2.2       19.98        19.98
# 168433             Home Delivery - CoD  12.0   2.2       19.98        19.98
# 168434             Home Delivery - CoD   8.0   1.3       12.98        12.98
# 168435             Home Delivery - CoD   8.0   1.3       12.98        12.98
# 168436             Home Delivery - CoD   8.0   1.8       12.98        12.98
#
# [168437 rows x 10 columns]

# %%
from tqdm import tqdm

# %%
df_answer = pd.DataFrame(columns=['MAGIC_KEY', 'BOX_ID'])

#df_answer.dtypes

df_answer['MAGIC_KEY'] = df_final['MAGIC_KEY']
df_answer['BOX_ID'] = df_final['BOX_ID']

#df_answer = df_answer.assign(BOX_ID = 0)

# df2 = df.assign(Tutors='NAN')
#df_answer

problem_df = problem_df.assign(BOX_ID = 0)

problem_df

for i in tqdm(range(len(problem_df))):

  val = problem_df.iloc[i, 0]
  #print(val)
  if val in df_answer['MAGIC_KEY'].values:

    #print(id)
    res_df =  df_answer.loc[df_answer['MAGIC_KEY'] == val]
    s = res_df['BOX_ID']

    counts = s.value_counts()
    # print the most frequent value
    #print(counts.index[0])
    problem_df.iloc[i, 1] = counts.index[0]


#problem_df
# Out:
# 100%|██████████| 43518/43518 [24:49<00:00, 29.22it/s]

# %%
problem_df
problem_df.to_csv('data.csv', index=False)
